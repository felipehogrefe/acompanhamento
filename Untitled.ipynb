# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import pandas as pd

# %%
key = 'P8Z69S2VPW8P5CUF'

ts = TimeSeries(key=key, output_format='pandas')

# %%
result = ts.get_symbol_search('ATEA3')[0]

# %%
len(result)
# Out:
# 0

# %%
result.sort_values(by=result['9. matchScore'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-a4bf3b7896cb> in <module>
# ----> 1 result.sort_values(by=result['9. matchScore'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5292
#    5293             by = by[0]
# -> 5294             k = self._get_label_or_level_values(by, axis=axis)
#    5295
#    5296             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: date
# 1970-01-01    0.8000
# Name: 9. matchScore, dtype: object

# %%
dados, meta_dados = ts.get_daily(symbol='GOGL34.SA', outputsize='full')

# %%
dados
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2021-09-17   101.13   101.80   98.91     99.19   130867.0
# 2021-09-16   101.00   101.25   99.72    101.13    75759.0
# 2021-09-15    99.90   101.04   99.11    100.95   110610.0
# 2021-09-14    99.40   100.02   98.71     99.45   116626.0
# 2021-09-13    98.65    99.50   98.33     98.52    81281.0
# ...             ...      ...     ...       ...        ...
# 2016-05-13   101.50   101.73  101.50    101.65     8500.0
# 2016-05-12   100.95   101.36  100.95    101.02     8400.0
# 2016-05-11   101.50   101.50  100.85    100.85     8000.0
# 2016-05-10   102.80   102.80  100.96    101.70    35600.0
# 2016-05-09   102.00   103.40  101.00    103.25    55700.0
#
# [1287 rows x 5 columns]

# %%
for index, row in dados.iterrows():
    print(index, row['1. open'])
# Out:
# 2021-09-17 00:00:00 101.13
# 2021-09-16 00:00:00 101.0
# 2021-09-15 00:00:00 99.9
# 2021-09-14 00:00:00 99.4
# 2021-09-13 00:00:00 98.65
# 2021-09-10 00:00:00 100.0
# 2021-09-09 00:00:00 101.8
# 2021-09-08 00:00:00 100.4
# 2021-09-06 00:00:00 100.0
# 2021-09-03 00:00:00 99.1
# 2021-09-02 00:00:00 100.67
# 2021-09-01 00:00:00 100.1
# 2021-08-31 00:00:00 99.99
# 2021-08-30 00:00:00 100.84
# 2021-08-27 00:00:00 99.49
# 2021-08-26 00:00:00 98.71
# 2021-08-25 00:00:00 99.0
# 2021-08-24 00:00:00 100.15
# 2021-08-23 00:00:00 98.8
# 2021-08-20 00:00:00 98.7
# 2021-08-19 00:00:00 97.47
# 2021-08-18 00:00:00 96.7
# 2021-08-17 00:00:00 97.0
# 2021-08-16 00:00:00 96.5
# 2021-08-13 00:00:00 96.08
# 2021-08-12 00:00:00 95.36
# 2021-08-11 00:00:00 94.9
# 2021-08-10 00:00:00 96.2
# 2021-08-09 00:00:00 95.31
# 2021-08-06 00:00:00 95.4
# 2021-08-05 00:00:00 93.02
# 2021-08-04 00:00:00 93.83
# 2021-08-03 00:00:00 94.3
# 2021-08-02 00:00:00 93.1
# 2021-07-30 00:00:00 92.01
# 2021-07-29 00:00:00 92.54
# ...

# %%
dados
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2021-09-17   101.13   101.80   98.91     99.19   130867.0
# 2021-09-16   101.00   101.25   99.72    101.13    75759.0
# 2021-09-15    99.90   101.04   99.11    100.95   110610.0
# 2021-09-14    99.40   100.02   98.71     99.45   116626.0
# 2021-09-13    98.65    99.50   98.33     98.52    81281.0
# ...             ...      ...     ...       ...        ...
# 2016-05-13   101.50   101.73  101.50    101.65     8500.0
# 2016-05-12   100.95   101.36  100.95    101.02     8400.0
# 2016-05-11   101.50   101.50  100.85    100.85     8000.0
# 2016-05-10   102.80   102.80  100.96    101.70    35600.0
# 2016-05-09   102.00   103.40  101.00    103.25    55700.0
#
# [1287 rows x 5 columns]

# %%
data_correcao = '2020-10-21'

# %%
meta_dados
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'GOGL34.SA',
#  '3. Last Refreshed': '2021-09-17',
#  '4. Output Size': 'Full size',
#  '5. Time Zone': 'US/Eastern'}

# %%
faixa_dados = dados[dados['Date'].dt.date.astype(str) <= '2020-10-21']['6. close cor']
for idx in range(len(dados)-len(faixa_dados)-1, len(dados)):
    print(dados.iloc[[idx]]['6. close cor'], dados.iloc[[idx]]['1. open'])
    print('***********')
    #faixa_dados.iloc[[idx]]['6. close cor'] = dados.iloc[[idx]]['4. close']/15
# Out:
# date
# 2020-10-22    60.02
# Name: 6. close cor, dtype: float64 date
# 2020-10-22    59.1
# Name: 1. open, dtype: float64
# ***********
# date
# 2020-10-21    356.17
# Name: 6. close cor, dtype: float64 date
# 2020-10-21    350.73
# Name: 1. open, dtype: float64
# ***********
# date
# 2020-10-20    355.0
# Name: 6. close cor, dtype: float64 date
# 2020-10-20    345.0
# Name: 1. open, dtype: float64
# ***********
# date
# 2020-10-19    344.0
# Name: 6. close cor, dtype: float64 date
# 2020-10-19    355.0
# Name: 1. open, dtype: float64
# ***********
# date
# 2020-10-16    355.0
# Name: 6. close cor, dtype: float64 date
# 2020-10-16    351.43
# Name: 1. open, dtype: float64
# ***********
# date
# 2020-10-15    351.42
# Name: 6. close cor, dtype: float64 date
# 2020-10-15    350.0
# Name: 1. open, dtype: float64
# ***********
# date
# 2020-10-14    352.1
# Name: 6. close cor, dtype: float64 date
# 2020-10-14    352.25
# Name: 1. open, dtype: float64
# ***********
# date
# ...

# %%
faixa_dados
# Out:
# date
# 2020-10-21    356.17
# 2020-10-20    355.00
# 2020-10-19    344.00
# 2020-10-16    355.00
# 2020-10-15    351.42
#                ...
# 2016-05-13    101.65
# 2016-05-12    101.02
# 2016-05-11    100.85
# 2016-05-10    101.70
# 2016-05-09    103.25
# Name: 6. close cor, Length: 1063, dtype: float64

# %%
recente = dados[dados['Date'].dt.date.astype(str) >= '2020-10-21'][dados['Date'].dt.date.astype(str) <= '2020-10-23']
# Out:
# <ipython-input-84-d5361347fd54>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   recente = dados[dados['Date'].dt.date.astype(str) >= '2020-10-20'][dados['Date'].dt.date.astype(str) <= '2020-10-23']

# %%
recente['4. close'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dados['4. close']
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2021-09-16   101.00   101.25   99.72    101.13    75499.0
# 2021-09-15    99.90   101.04   99.11    100.95   110610.0
# 2021-09-14    99.40   100.02   98.71     99.45   116626.0
# 2021-09-13    98.65    99.50   98.33     98.52    81281.0
# 2021-09-10   100.00   100.79   98.70     98.98   142229.0
# ...             ...      ...     ...       ...        ...
# 2016-05-13   101.50   101.73  101.50    101.65     8500.0
# 2016-05-12   100.95   101.36  100.95    101.02     8400.0
# 2016-05-11   101.50   101.50  100.85    100.85     8000.0
# 2016-05-10   102.80   102.80  100.96    101.70    35600.0
# 2016-05-09   102.00   103.40  101.00    103.25    55700.0
#
# [1286 rows x 5 columns]

# %% [markdown]
# dados
